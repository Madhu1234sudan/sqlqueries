# %%
SELECT * from customers
# Out:
# (5 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 1  | Maria      | Germany | 350
# 2  |  John      | USA     | 900
# 3  | Georg      | UK      | 750
# 4  | Martin     | Germany | 500
# 5  | Peter      | USA     | 0
# (5 rows)
#
# Total execution time: 00:00:00.050

# %%
--  select all the customers whose name starting with 'M'
select * from customers
where first_name LIKE 'M%'
# Out:
# (2 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 1  | Maria      | Germany | 350
# 4  | Martin     | Germany | 500
# (2 rows)
#
# Total execution time: 00:00:00.015

# %%
-- find all the customers whoes name ends with 'N'

select * from 
customers 
where first_name LIKE '%N'
# Out:
# (2 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 2  |  John      | USA     | 900
# 4  | Martin     | Germany | 500
# (2 rows)
#
# Total execution time: 00:00:00.031

# %%
-- find customers whose name contains with 'r'

select * 
from customers
where first_name LIKE '%r%'
# Out:
# (4 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 1  | Maria      | Germany | 350
# 3  | Georg      | UK      | 750
# 4  | Martin     | Germany | 500
# 5  | Peter      | USA     | 0
# (4 rows)
#
# Total execution time: 00:00:00.005

# %%
-- find the customers whose name consisting 'r' in the third position

select * 
from customers
where first_name LIKE '__r%'
# Out:
# (2 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 1  | Maria      | Germany | 350
# 4  | Martin     | Germany | 500
# (2 rows)
#
# Total execution time: 00:00:00.031

# %%
-- Retrieve all data from customers and orders in two different tables 

select * from customers

select * from orders
# Out:
# (5 rows affected)
# (4 rows affected)
#
# id | first_name | country | score
# ---+------------+---------+------
# 1  | Maria      | Germany | 350
# 2  |  John      | USA     | 900
# 3  | Georg      | UK      | 750
# 4  | Martin     | Germany | 500
# 5  | Peter      | USA     | 0
# (5 rows)
#
# order_id | customer_id | order_date | sales
# ---------+-------------+------------+------
# 1001     | 1           | 2021-01-11 | 35
# 1002     | 2           | 2021-04-05 | 15
# 1003     | 3           | 2021-06-18 | 20
# 1004     | 6           | 2021-08-31 | 10
# (4 rows)
#
# Total execution time: 00:00:00.015

# %%
-- get all customers along with their orders but only for a customers with who have placed an order

select * 
from customers as c 
INNER JOIN orders as o 
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | country | score | order_id | customer_id | order_date | sales
# ---+------------+---------+-------+----------+-------------+------------+------
# 1  | Maria      | Germany | 350   | 1001     | 1           | 2021-01-11 | 35
# 2  |  John      | USA     | 900   | 1002     | 2           | 2021-04-05 | 15
# 3  | Georg      | UK      | 750   | 1003     | 3           | 2021-06-18 | 20
# (3 rows)
#
# Total execution time: 00:00:00.009

# %%
select
    c.id,
    c.first_name,
    o.customer_id,
    o.sales
from customers as c
inner join 
orders as o 
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 2           | 15
# 3  | Georg      | 3           | 20
# (3 rows)
#
# Total execution time: 00:00:01.546

# %%
select
    c.id,
    c.first_name,
    o.customer_id,
    o.sales
from customers as c 
inner join 
orders as o
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 2           | 15
# 3  | Georg      | 3           | 20
# (3 rows)
#
# Total execution time: 00:00:00.015

# %%
select 
    c.id,
    c.first_name,
    o.customer_id,
    o.sales 
from customers as c
inner join 
orders as o
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 2           | 15
# 3  | Georg      | 3           | 20
# (3 rows)
#
# Total execution time: 00:00:02.027

# %%
SELECT 
    c.id,
    c.first_name,
    o.customer_id,
    o.sales
from customers as c  
inner join 
orders as o  
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 2           | 15
# 3  | Georg      | 3           | 20
# (3 rows)
#
# Total execution time: 00:00:00.087

# %%
select 
    c.id,
    c.first_name, 
    o.order_id,
    o.sales 
from customers c  
inner join 
orders as o  
on c.id = o.customer_id
# Out:
# (3 rows affected)
#
# id | first_name | order_id | sales
# ---+------------+----------+------
# 1  | Maria      | 1001     | 35
# 2  |  John      | 1002     | 15
# 3  | Georg      | 1003     | 20
# (3 rows)
#
# Total execution time: 00:00:00.013

# %%
-- get all customers along witht their orders, including those without orders 

select 
    c.id,
    c.first_name, 
    o.order_id, 
    o.sales 
from customers as c   
left join 
orders as o  
on c.id = o.customer_id
# Out:
# (5 rows affected)
#
# id | first_name | order_id | sales
# ---+------------+----------+------
# 1  | Maria      | 1001     | 35
# 2  |  John      | 1002     | 15
# 3  | Georg      | 1003     | 20
# 4  | Martin     | NULL     | NULL
# 5  | Peter      | NULL     | NULL
# (5 rows)
#
# Total execution time: 00:00:00.101

# %%
-- get all customers along with their orders, including orders without matching customers 

select 
    c.id, 
    c.first_name,
    o.order_id,
    o.sales 
from orders o  
left join customers c  
on c.id = o.customer_id
# Out:
# (4 rows affected)
#
# id   | first_name | order_id | sales
# -----+------------+----------+------
# 1    | Maria      | 1001     | 35
# 2    |  John      | 1002     | 15
# 3    | Georg      | 1003     | 20
# NULL | NULL       | 1004     | 10
# (4 rows)
#
# Total execution time: 00:00:28.411

# %%
-- get all customers and all orders, even if there is not matching records

select 
    c.id, 
    c.first_name, 
    o.order_id,
    o.sales 
from customers as c  
full join 
orders as o
on c.id = o.customer_id
# Out:
# (6 rows affected)
#
# id   | first_name | order_id | sales
# -----+------------+----------+------
# 1    | Maria      | 1001     | 35
# 2    |  John      | 1002     | 15
# 3    | Georg      | 1003     | 20
# 4    | Martin     | NULL     | NULL
# 5    | Peter      | NULL     | NULL
# NULL | NULL       | 1004     | 10
# (6 rows)
#
# Total execution time: 00:00:05.934

# %%
select * 
from customers as c  
left join 
orders as o  
on o.customer_id = c.id
where o.customer_id is null
# Out:
# (2 rows affected)
#
# id | first_name | country | score | order_id | customer_id | order_date | sales
# ---+------------+---------+-------+----------+-------------+------------+------
# 4  | Martin     | Germany | 500   | NULL     | NULL        | NULL       | NULL
# 5  | Peter      | USA     | 0     | NULL     | NULL        | NULL       | NULL
# (2 rows)
#
# Total execution time: 00:00:00.004

# %%
-- Left anti join 
-- find the customers who haven't order anything
select 
    c.id,
    c.first_name, 
    o.customer_id,
    o.sales 
from customers as c
left join 
orders as o 
on c.id = o.customer_id  
where o.customer_id is NULL
# Out:
# (2 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 4  | Martin     | NULL        | NULL
# 5  | Peter      | NULL        | NULL
# (2 rows)
#
# Total execution time: 00:00:00.008

# %%
-- Right Anti Join 
-- Get all the customers without matching the orders

select 
    c.id,
    c.first_name, 
    o.customer_id,
    o.sales  
from customers as c
right join 
orders as o
on o.customer_id = c.id   
-- where c.id is NULL
# Out:
# (4 rows affected)
#
# id   | first_name | customer_id | sales
# -----+------------+-------------+------
# 1    | Maria      | 1           | 35
# 2    |  John      | 2           | 15
# 3    | Georg      | 3           | 20
# NULL | NULL       | 6           | 10
# (4 rows)
#
# Total execution time: 00:00:14.747

# %%
-- get all the customers without any order 

select 
    c.id, 
    c.first_name,
    o.customer_id,
    o.sales
from orders as o  
left join 
customers as c  
on o.customer_id = c.id
where c.id is null
# Out:
# (1 row affected)
#
# id   | first_name | customer_id | sales
# -----+------------+-------------+------
# NULL | NULL       | 6           | 10
# (1 row)
#
# Total execution time: 00:00:00.007

# %%
-- Full Anti join 
-- find all customers without orders and ll orders without customers

select 
    c.id, 
    c.first_name, 
    o.customer_id,
    o.sales 
from customers as c  
full join 
orders as o
on c.id = o.customer_id
where c.id is null 
or  
o.customer_id is null
# Out:
# (3 rows affected)
#
# id   | first_name | customer_id | sales
# -----+------------+-------------+------
# 4    | Martin     | NULL        | NULL
# 5    | Peter      | NULL        | NULL
# NULL | NULL       | 6           | 10
# (3 rows)
#
# Total execution time: 00:00:00.029

# %%
-- find all customers along with their orders, but only for customers who have placed an order
-- without using the inner join

select 
    c.id, 
    c.first_name,
    o.customer_id,
    o.sales 
from customers as c 
left join 
orders as o
on c.id = o.customer_id
where o.customer_id is not null
# Out:
# (3 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 2           | 15
# 3  | Georg      | 3           | 20
# (3 rows)
#
# Total execution time: 00:00:00.010

# %%
--  Cross Join 
-- Get all possible combination of customers and orders 

select 
    c.id, 
    c.first_name,
    o.customer_id,
    o.sales 
from customers as c  
cross join 
orders as o
# Out:
# (20 rows affected)
#
# id | first_name | customer_id | sales
# ---+------------+-------------+------
# 1  | Maria      | 1           | 35
# 2  |  John      | 1           | 35
# 3  | Georg      | 1           | 35
# 4  | Martin     | 1           | 35
# 5  | Peter      | 1           | 35
# 1  | Maria      | 2           | 15
# 2  |  John      | 2           | 15
# 3  | Georg      | 2           | 15
# 4  | Martin     | 2           | 15
# 5  | Peter      | 2           | 15
# 1  | Maria      | 3           | 20
# 2  |  John      | 3           | 20
# 3  | Georg      | 3           | 20
# 4  | Martin     | 3           | 20
# 5  | Peter      | 3           | 20
# 1  | Maria      | 6           | 10
# 2  |  John      | 6           | 10
# 3  | Georg      | 6           | 10
# 4  | Martin     | 6           | 10
# 5  | Peter      | 6           | 10
# (20 rows)
#
# Total execution time: 00:00:02.004

# %%
-- Task ==> Using SalesDB, Retrieve a list of all orders, along with the related 
-- customer, product and employee details. 
-- For each order, display:
/* orderID
    Customer's name
    Product name
    Sales
    Price
    Sales Person's name
*/


select 
    o.orderID,
    o.Sales,
    c.FirstName as CustomersFirstName,
    c.LastName as CustomersLastName,
    p.Product as ProductName,
    p.Price,
    e.FirstName as EmployeeFirstName,
    e.LastName as EmployeeLastName
from Sales.Orders as o
left join 
Sales.Customers as c 
on o.CustomerID = c.CustomerID
left join 
Sales.Products as p
on o.ProductID = p.ProductID
left join 
sales.Employees as e    
on o.SalesPersonID = e.EmployeeID
# Out:
# (10 rows affected)
#
# orderID | Sales | CustomersFirstName | CustomersLastName | ProductName | Price | EmployeeFirstName | EmployeeLastName
# --------+-------+--------------------+-------------------+-------------+-------+-------------------+-----------------
# 1       | 10    | Kevin              | Brown             | Bottle      | 10    | Mary              | NULL
# 2       | 15    | Mary               | NULL              | Tire        | 15    | Mary              | NULL
# 3       | 20    | Jossef             | Goldberg          | Bottle      | 10    | Carol             | Baker
# 4       | 60    | Jossef             | Goldberg          | Gloves      | 30    | Mary              | NULL
# 5       | 25    | Kevin              | Brown             | Caps        | 25    | Carol             | Baker
# 6       | 50    | Mary               | NULL              | Caps        | 25    | Carol             | Baker
# ...

# %%
-- SET OPERATORS 
-- 1. Union 

select 
    FirstName,
    LastName
from Sales.Customers

UNION

select 
    FirstName,
    LastName
from Sales.Employees
# Out:
# (8 rows affected)
#
# FirstName | LastName
# ----------+---------
# Anna      | Adams
# Carol     | Baker
# Frank     | Lee
# Jossef    | Goldberg
# Kevin     | Brown
# Mark      | Schwarz
# Mary      | NULL
# Michael   | Ray
# (8 rows)
#
# Total execution time: 00:00:00.079

# %%
select 
    first_name,
    country,
    CONCAT( first_name,' ',country) as Name_And_Country,
    LOWER(first_name) as lower_case_name,
    UPPER(first_name) as upper_case_name
from Customers
# Out:
# (5 rows affected)
#
# first_name | country | Name_And_Country | lower_case_name | upper_case_name
# -----------+---------+------------------+-----------------+----------------
# Maria      | Germany | Maria Germany    | maria           | MARIA
#  John      | USA     |  John USA        |  john           |  JOHN
# Georg      | UK      | Georg UK         | georg           | GEORG
# Martin     | Germany | Martin Germany   | martin          | MARTIN
# Peter      | USA     | Peter USA        | peter           | PETER
# (5 rows)
#
# Total execution time: 00:00:00.008

# %%
select
    first_name,
    len(first_name) AS length,
from customers 
where len(first_name) <> len(trim(first_name)) as checking
# Out:
# Msg 156, Level 15, State 1, Line 4
# Incorrect syntax near the keyword 'from'.
# Total execution time: 00:00:00

# %%
select 
'1234-567-890',
replace('1234-567-890', '-', '')
# Out:
# (1 row affected)
#
# (No column name) | (No column name)
# -----------------+-----------------
# 1234-567-890     | 1234567890
# (1 row)
#
# Total execution time: 00:00:00.031

# %%
select 
    first_name,
    LEFT(trim(first_name), 2) as First_two_characters,
    right(trim(first_name),2) as Last_two_characters,
    substring(first_name, 2, 2) as fetched_characters
from customers
# Out:
# (5 rows affected)
#
# first_name | First_two_characters | Last_two_characters | (No column name)
# -----------+----------------------+---------------------+-----------------
# Maria      | Ma                   | ia                  | ar
#  John      | Jo                   | hn                  | Jo
# Georg      | Ge                   | rg                  | eo
# Martin     | Ma                   | in                  | ar
# Peter      | Pe                   | er                  | et
# (5 rows)
#
# Total execution time: 00:00:00.007

# %%
select 
    first_name,
    substring(trim(first_name), 2, len(first_name)) as updated_string
from customers
# Out:
# (5 rows affected)
#
# first_name | updated_string
# -----------+---------------
# Maria      | aria
#  John      | ohn
# Georg      | eorg
# Martin     | artin
# Peter      | eter
# (5 rows)
#
# Total execution time: 00:00:00.004

# %%
select 3.156,
ROUND(3.156, 2) as rounded
# Out:
# (1 row affected)
#
# (No column name) | rounded
# -----------------+--------
# 3.156            | 3.160
# (1 row)
#
# Total execution time: 00:00:00.014

# %%
select -10,
abs(-10)
# Out:
# (1 row affected)
#
# (No column name) | (No column name)
# -----------------+-----------------
# -10              | 10
# (1 row)
#
# Total execution time: 00:00:01.009

# %%
select 
    day(orderDate),
    month(shipDate)

from Sales.Orders
# Out:
# Query execution was canceled.

# %%
select 
    orderDate,
    creationtime,
    year(orderDate),
    month(creationtime),
    day(orderDate)
from

# %%
SELECT 
    req.session_id
    , req.total_elapsed_time AS duration_ms
    , req.cpu_time AS cpu_time_ms
    , req.total_elapsed_time - req.cpu_time AS wait_time
    , req.logical_reads
    , SUBSTRING (REPLACE (REPLACE (SUBSTRING (ST.text, (req.statement_start_offset/2) + 1, 
       ((CASE statement_end_offset
           WHEN -1
           THEN DATALENGTH(ST.text)  
           ELSE req.statement_end_offset
         END - req.statement_start_offset)/2) + 1) , CHAR(10), ' '), CHAR(13), ' '), 
      1, 512)  AS statement_text  
FROM sys.dm_exec_requests AS req
    CROSS APPLY sys.dm_exec_sql_text(req.sql_handle) AS ST
ORDER BY total_elapsed_time DESC;
# Out:
# (1 row affected)
#
# session_id | duration_ms | cpu_time_ms | wait_time | logical_reads | statement_text
# -----------+-------------+-------------+-----------+---------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# 56         | 29          | 28          | 1         | 328           | SELECT       req.session_id      , req.total_elapsed_time AS duration_ms      , req.cpu_time AS cpu_time_ms      , req.total_elapsed_time - req.cpu_time AS wait_time      , req.logical_reads      , SUBSTRING (REPLACE (REPLACE (SUBSTRING (ST.text, (req.statement_start_offset/2) + 1,          ((CASE statement_end_offset             WHEN -1             THEN DATALENGTH(ST.text)               ELSE req.statement_end_offset           END - req.statement_start_offset)/2) + 1) , CHAR(10), ' '), CHAR(13), ' '),
# (1 row)
#
# ...

# %%
SELECT t.text,
     (qs.total_elapsed_time/1000) / qs.execution_count AS avg_elapsed_time,
     (qs.total_worker_time/1000) / qs.execution_count AS avg_cpu_time,
     ((qs.total_elapsed_time/1000) / qs.execution_count ) - ((qs.total_worker_time/1000) / qs.execution_count) AS avg_wait_time,
     qs.total_logical_reads / qs.execution_count AS avg_logical_reads,
     qs.total_logical_writes / qs.execution_count AS avg_writes,
     (qs.total_elapsed_time/1000) AS cumulative_elapsed_time_all_executions
FROM sys.dm_exec_query_stats qs
     CROSS apply sys.Dm_exec_sql_text (sql_handle) t
WHERE t.text like select 
    day(orderDate),
    month(shipDate)

from Sales.Orders
-- Replace <Your Query> with your query or the beginning part of your query. The special chars like '[','_','%','^' in the query should be escaped.
ORDER BY (qs.total_elapsed_time / qs.execution_count) DESC
# Out:
# Msg 156, Level 15, State 1, Line 10
# Incorrect syntax near the keyword 'select'.
# Total execution time: 00:00:00.007

# %%
import time

start = time.time()

df = pd.read_sql("SELECT COUNT(*) FROM sales.orders", conn)

print("Time:", time.time() - start)
# Out:
# Msg 102, Level 15, State 1, Line 3
# Incorrect syntax near 'start'.
# Msg 128, Level 15, State 1, Line 7
# The name "Time:" is not permitted in this context. Valid expressions are constants, constant expressions, and (in some contexts) variables. Column names are not permitted.
# Total execution time: 00:00:00.005

# %%
select * from sales.orders
# Out:
# (10 rows affected)
#
# OrderID | ProductID | CustomerID | SalesPersonID | OrderDate  | ShipDate   | OrderStatus | ShipAddress        | BillAddress   | Quantity | Sales | CreationTime
# --------+-----------+------------+---------------+------------+------------+-------------+--------------------+---------------+----------+-------+----------------------------
# 1       | 101       | 2          | 3             | 2025-01-01 | 2025-01-05 | Delivered   | 9833 Mt. Dias Blv. | 1226 Shoe St. | 1        | 10    | 2025-01-01 12:34:56.0000000
# 2       | 102       | 3          | 3             | 2025-01-05 | 2025-01-10 | Shipped     | 250 Race Court     | NULL          | 1        | 15    | 2025-01-05 23:22:04.0000000
# 3       | 101       | 1          | 5             | 2025-01-10 | 2025-01-25 | Delivered   | 8157 W. Book       | 8157 W. Book  | 2        | 20    | 2025-01-10 18:24:08.0000000
# ...
