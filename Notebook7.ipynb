# %%
USE SalesDB
# Out:
# Commands completed successfully.
# Total execution time: 00:00:00.002

# %%
select * 
FROM sales.orders
# Out:
# (10 rows affected)
#
# OrderID | ProductID | CustomerID | SalesPersonID | OrderDate  | ShipDate   | OrderStatus | ShipAddress        | BillAddress   | Quantity | Sales | CreationTime
# --------+-----------+------------+---------------+------------+------------+-------------+--------------------+---------------+----------+-------+----------------------------
# 1       | 101       | 2          | 3             | 2025-01-01 | 2025-01-05 | Delivered   | 9833 Mt. Dias Blv. | 1226 Shoe St. | 1        | 10    | 2025-01-01 12:34:56.0000000
# 2       | 102       | 3          | 3             | 2025-01-05 | 2025-01-10 | Shipped     | 250 Race Court     | NULL          | 1        | 15    | 2025-01-05 23:22:04.0000000
# 3       | 101       | 1          | 5             | 2025-01-10 | 2025-01-25 | Delivered   | 8157 W. Book       | 8157 W. Book  | 2        | 20    | 2025-01-10 18:24:08.0000000
# ...

# %%
-- 1. Row_Number() OVER(ORDER BY Sasles DESC)
-- IT DOESN'T HANDLE TIES AND it does leave any gaps 
-- Rank the orders based on their sales from highest to lowest 

select
    orderid,
    productid,
    sales,
    ROW_NUMBER() OVER(ORDER BY sales DESC) salesrank_row 
FROM sales.orders
# Out:
# (10 rows affected)
#
# orderid | productid | sales | salesrank_row
# --------+-----------+-------+--------------
# 8       | 101       | 90    | 1
# 4       | 105       | 60    | 2
# 10      | 102       | 60    | 3
# 6       | 104       | 50    | 4
# 7       | 102       | 30    | 5
# 5       | 104       | 25    | 6
# 9       | 101       | 20    | 7
# 3       | 101       | 20    | 8
# 2       | 102       | 15    | 9
# 1       | 101       | 10    | 10
# (10 rows)
#
# Total execution time: 00:00:01.008

# %%
SELECT 
*
FROM sales.orders
# Out:
# (10 rows affected)
#
# OrderID | ProductID | CustomerID | SalesPersonID | OrderDate  | ShipDate   | OrderStatus | ShipAddress        | BillAddress   | Quantity | Sales | CreationTime
# --------+-----------+------------+---------------+------------+------------+-------------+--------------------+---------------+----------+-------+----------------------------
# 1       | 101       | 2          | 3             | 2025-01-01 | 2025-01-05 | Delivered   | 9833 Mt. Dias Blv. | 1226 Shoe St. | 1        | 10    | 2025-01-01 12:34:56.0000000
# 2       | 102       | 3          | 3             | 2025-01-05 | 2025-01-10 | Shipped     | 250 Race Court     | NULL          | 1        | 15    | 2025-01-05 23:22:04.0000000
# 3       | 101       | 1          | 5             | 2025-01-10 | 2025-01-25 | Delivered   | 8157 W. Book       | 8157 W. Book  | 2        | 20    | 2025-01-10 18:24:08.0000000
# ...
