# %%
SELECT
*
FROM Employees
# Out:
# (10 rows affected)
#
# employee_id | first_name | last_name | gender | salary   | hire_date  | department_id | manager_id
# ------------+------------+-----------+--------+----------+------------+---------------+-----------
# 101         | Amit       | Sharma    | Male   | 90000.00 | 2020-01-15 | 2             | NULL
# 102         | Priya      | Verma     | Female | 85000.00 | 2019-03-10 | 1             | NULL
# 103         | Rahul      | Mehta     | Male   | 70000.00 | 2021-07-22 | 2             | 101
# 104         | Sneha      | Iyer      | Female | 65000.00 | 2022-05-18 | 3             | 102
# 105         | Arjun      | Reddy     | Male   | 72000.00 | 2020-11-11 | 4             | 101
# 106         | Neha       | Kapoor    | Female | 68000.00 | 2021-09-09 | 5             | 102
# 107         | Vikram     | Singh     | Male   | 95000.00 | 2018-12-01 | 3             | NULL
# 108         | Pooja      | Nair      | Female | 60000.00 | 2023-02-14 | 4             | 105
# ...
